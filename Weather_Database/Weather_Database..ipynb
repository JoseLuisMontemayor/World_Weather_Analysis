# %%
# import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# import the requests library
import requests

# import the API key
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=78838d8144f91abe34a167f44d57d42e

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Get the nearest city using the citypy module
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 783

# %%
# Perform an API call with the OpenWeatherMap

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | geraldton
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 1 | champerico
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | soe
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | atar
# Processing Record 10 of Set 1 | coihaique
# Processing Record 11 of Set 1 | georgetown
# Processing Record 12 of Set 1 | dudinka
# Processing Record 13 of Set 1 | mahebourg
# Processing Record 14 of Set 1 | kysyl-syr
# Processing Record 15 of Set 1 | port angeles
# Processing Record 16 of Set 1 | castro
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | houlton
# Processing Record 19 of Set 1 | ko samui
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | kaeo
# Processing Record 22 of Set 1 | naze
# Processing Record 23 of Set 1 | east london
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | kerema
# Processing Record 26 of Set 1 | grand-santi
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | kodiak
# Processing Record 29 of Set 1 | qaqortoq
# Processing Record 30 of Set 1 | bambous virieux
# Processing Record 31 of Set 1 | jalalabad
# Processing Record 32 of Set 1 | port elizabeth
# Processing Record 33 of Set 1 | teya
# Processing Record 34 of Set 1 | salalah
# Processing Record 35 of Set 1 | thompson
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | kahului
# Processing Record 38 of Set 1 | bredasdorp
# Processing Record 39 of Set 1 | faanui
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | lebu
# Processing Record 42 of Set 1 | castlemaine
# Processing Record 43 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 1 | lingyuan
# Processing Record 45 of Set 1 | cape town
# Processing Record 46 of Set 1 | nyurba
# Processing Record 47 of Set 1 | bonavista
# Processing Record 48 of Set 1 | new norfolk
# Processing Record 49 of Set 1 | rikitea
# Processing Record 50 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 1 of Set 2 | erenhot
# Processing Record 2 of Set 2 | ntcheu
# Processing Record 3 of Set 2 | sao filipe
# Processing Record 4 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 2 | singkang
# Processing Record 6 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 2 | qaanaaq
# Processing Record 8 of Set 2 | chokurdakh
# Processing Record 9 of Set 2 | klaksvik
# Processing Record 10 of Set 2 | eckernforde
# Processing Record 11 of Set 2 | khandyga
# Processing Record 12 of Set 2 | inderborskiy
# City not found. Skipping...
# Processing Record 13 of Set 2 | zbarazh
# Processing Record 14 of Set 2 | parchim
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | mbandaka
# Processing Record 17 of Set 2 | saint-augustin
# Processing Record 18 of Set 2 | hualmay
# Processing Record 19 of Set 2 | laguna
# Processing Record 20 of Set 2 | anadyr
# Processing Record 21 of Set 2 | moba
# Processing Record 22 of Set 2 | nikolskoye
# Processing Record 23 of Set 2 | florence
# Processing Record 24 of Set 2 | airai
# Processing Record 25 of Set 2 | svetlaya
# Processing Record 26 of Set 2 | kapaa
# Processing Record 27 of Set 2 | kangaatsiaq
# Processing Record 28 of Set 2 | the valley
# Processing Record 29 of Set 2 | tasiilaq
# Processing Record 30 of Set 2 | hamilton
# Processing Record 31 of Set 2 | walvis bay
# Processing Record 32 of Set 2 | matamoros
# Processing Record 33 of Set 2 | kavieng
# Processing Record 34 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 2 | hasaki
# Processing Record 36 of Set 2 | yellowknife
# Processing Record 37 of Set 2 | biscarrosse
# Processing Record 38 of Set 2 | prince rupert
# Processing Record 39 of Set 2 | port hardy
# Processing Record 40 of Set 2 | ajdabiya
# Processing Record 41 of Set 2 | jutai
# Processing Record 42 of Set 2 | kadykchan
# City not found. Skipping...
# Processing Record 43 of Set 2 | iqaluit
# Processing Record 44 of Set 2 | luwuk
# Processing Record 45 of Set 2 | vardo
# Processing Record 46 of Set 2 | seoul
# Processing Record 47 of Set 2 | puerto ayora
# Processing Record 48 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 49 of Set 2 | plouzane
# Processing Record 50 of Set 2 | kununurra
# Processing Record 1 of Set 3 | torbay
# Processing Record 2 of Set 3 | udachnyy
# Processing Record 3 of Set 3 | khatanga
# Processing Record 4 of Set 3 | catuday
# Processing Record 5 of Set 3 | butaritari
# Processing Record 6 of Set 3 | arraial do cabo
# Processing Record 7 of Set 3 | ipixuna
# Processing Record 8 of Set 3 | san patricio
# Processing Record 9 of Set 3 | nishihara
# Processing Record 10 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 3 | high level
# Processing Record 12 of Set 3 | shirokiy
# Processing Record 13 of Set 3 | isangel
# Processing Record 14 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 3 | kaitangata
# Processing Record 16 of Set 3 | bantry
# Processing Record 17 of Set 3 | hilo
# Processing Record 18 of Set 3 | saskylakh
# Processing Record 19 of Set 3 | altay
# Processing Record 20 of Set 3 | punta arenas
# Processing Record 21 of Set 3 | avarua
# Processing Record 22 of Set 3 | samarai
# Processing Record 23 of Set 3 | broken hill
# Processing Record 24 of Set 3 | lagoa
# Processing Record 25 of Set 3 | praia da vitoria
# Processing Record 26 of Set 3 | morant bay
# Processing Record 27 of Set 3 | ancud
# Processing Record 28 of Set 3 | dargaville
# Processing Record 29 of Set 3 | bulgan
# Processing Record 30 of Set 3 | conceicao do araguaia
# Processing Record 31 of Set 3 | novyy urgal
# Processing Record 32 of Set 3 | mapiripan
# Processing Record 33 of Set 3 | narsaq
# Processing Record 34 of Set 3 | duluth
# Processing Record 35 of Set 3 | ordu
# Processing Record 36 of Set 3 | fortuna
# Processing Record 37 of Set 3 | olafsvik
# Processing Record 38 of Set 3 | sapucai
# Processing Record 39 of Set 3 | umm lajj
# Processing Record 40 of Set 3 | tukrah
# Processing Record 41 of Set 3 | guerrero negro
# Processing Record 42 of Set 3 | hithadhoo
# Processing Record 43 of Set 3 | chuy
# Processing Record 44 of Set 3 | villacarrillo
# Processing Record 45 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 3 | victoria
# Processing Record 47 of Set 3 | carauari
# Processing Record 48 of Set 3 | peniche
# Processing Record 49 of Set 3 | pitimbu
# Processing Record 50 of Set 3 | san quintin
# Processing Record 1 of Set 4 | brewster
# Processing Record 2 of Set 4 | amparafaravola
# Processing Record 3 of Set 4 | chesma
# Processing Record 4 of Set 4 | homer
# Processing Record 5 of Set 4 | tuatapere
# Processing Record 6 of Set 4 | melnikovo
# Processing Record 7 of Set 4 | hami
# Processing Record 8 of Set 4 | kitimat
# Processing Record 9 of Set 4 | luoyang
# Processing Record 10 of Set 4 | pacific grove
# Processing Record 11 of Set 4 | shimoda
# Processing Record 12 of Set 4 | ilulissat
# Processing Record 13 of Set 4 | port lincoln
# Processing Record 14 of Set 4 | jonesboro
# Processing Record 15 of Set 4 | talnakh
# Processing Record 16 of Set 4 | norman wells
# Processing Record 17 of Set 4 | ponta do sol
# Processing Record 18 of Set 4 | cabo san lucas
# Processing Record 19 of Set 4 | coruripe
# Processing Record 20 of Set 4 | kargasok
# Processing Record 21 of Set 4 | sultanpur
# Processing Record 22 of Set 4 | rosarito
# Processing Record 23 of Set 4 | viedma
# Processing Record 24 of Set 4 | arkhangelsk
# Processing Record 25 of Set 4 | chimbote
# Processing Record 26 of Set 4 | saint-pierre
# Processing Record 27 of Set 4 | mangochi
# Processing Record 28 of Set 4 | nizhniy kuranakh
# Processing Record 29 of Set 4 | tamworth
# Processing Record 30 of Set 4 | shelburne
# Processing Record 31 of Set 4 | fare
# Processing Record 32 of Set 4 | nattam
# Processing Record 33 of Set 4 | taltal
# Processing Record 34 of Set 4 | longyearbyen
# Processing Record 35 of Set 4 | huambo
# Processing Record 36 of Set 4 | dedza
# Processing Record 37 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 4 | guelengdeng
# City not found. Skipping...
# Processing Record 39 of Set 4 | misratah
# Processing Record 40 of Set 4 | bucerias
# Processing Record 41 of Set 4 | port alfred
# Processing Record 42 of Set 4 | wisconsin rapids
# Processing Record 43 of Set 4 | tuktoyaktuk
# Processing Record 44 of Set 4 | saint-denis
# Processing Record 45 of Set 4 | esperance
# Processing Record 46 of Set 4 | sao joao da barra
# Processing Record 47 of Set 4 | abeche
# Processing Record 48 of Set 4 | nome
# Processing Record 49 of Set 4 | provideniya
# Processing Record 50 of Set 4 | dalvik
# Processing Record 1 of Set 5 | shingu
# Processing Record 2 of Set 5 | hvolsvollur
# Processing Record 3 of Set 5 | mangrol
# Processing Record 4 of Set 5 | nago
# Processing Record 5 of Set 5 | honiara
# Processing Record 6 of Set 5 | te anau
# Processing Record 7 of Set 5 | solginskiy
# Processing Record 8 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 5 | saldanha
# Processing Record 10 of Set 5 | vestmannaeyjar
# Processing Record 11 of Set 5 | ostroda
# Processing Record 12 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 13 of Set 5 | flinders
# Processing Record 14 of Set 5 | san policarpo
# Processing Record 15 of Set 5 | zyryanka
# Processing Record 16 of Set 5 | labuan
# Processing Record 17 of Set 5 | saint-felicien
# Processing Record 18 of Set 5 | londoko
# Processing Record 19 of Set 5 | boyle
# Processing Record 20 of Set 5 | lorengau
# Processing Record 21 of Set 5 | ostrovnoy
# Processing Record 22 of Set 5 | chebsara
# Processing Record 23 of Set 5 | ciudad bolivar
# Processing Record 24 of Set 5 | sur
# Processing Record 25 of Set 5 | murgab
# Processing Record 26 of Set 5 | dunedin
# Processing Record 27 of Set 5 | leiyang
# Processing Record 28 of Set 5 | clyde river
# Processing Record 29 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 30 of Set 5 | carutapera
# Processing Record 31 of Set 5 | yarada
# Processing Record 32 of Set 5 | tigil
# Processing Record 33 of Set 5 | saint-philippe
# Processing Record 34 of Set 5 | katsuura
# Processing Record 35 of Set 5 | aswan
# Processing Record 36 of Set 5 | bethel
# Processing Record 37 of Set 5 | eureka
# Processing Record 38 of Set 5 | buala
# Processing Record 39 of Set 5 | bengkulu
# Processing Record 40 of Set 5 | pevek
# Processing Record 41 of Set 5 | upernavik
# Processing Record 42 of Set 5 | sao felix do xingu
# Processing Record 43 of Set 5 | vondrozo
# Processing Record 44 of Set 5 | fort nelson
# Processing Record 45 of Set 5 | hambantota
# Processing Record 46 of Set 5 | inirida
# Processing Record 47 of Set 5 | ariquemes
# Processing Record 48 of Set 5 | sobolevo
# Processing Record 49 of Set 5 | gatton
# Processing Record 50 of Set 5 | jalu
# Processing Record 1 of Set 6 | binghamton
# Processing Record 2 of Set 6 | louis trichardt
# Processing Record 3 of Set 6 | paamiut
# Processing Record 4 of Set 6 | pleasanton
# Processing Record 5 of Set 6 | tingi
# Processing Record 6 of Set 6 | balkanabat
# Processing Record 7 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 6 | bilibino
# Processing Record 9 of Set 6 | henties bay
# Processing Record 10 of Set 6 | souillac
# Processing Record 11 of Set 6 | ahipara
# Processing Record 12 of Set 6 | samana
# Processing Record 13 of Set 6 | san cristobal
# Processing Record 14 of Set 6 | grandview
# Processing Record 15 of Set 6 | touros
# Processing Record 16 of Set 6 | mayumba
# Processing Record 17 of Set 6 | cherskiy
# Processing Record 18 of Set 6 | tulun
# Processing Record 19 of Set 6 | pisco
# Processing Record 20 of Set 6 | rio brilhante
# Processing Record 21 of Set 6 | sorland
# Processing Record 22 of Set 6 | santa barbara
# Processing Record 23 of Set 6 | sindor
# Processing Record 24 of Set 6 | dangriga
# Processing Record 25 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 6 | bay roberts
# Processing Record 27 of Set 6 | sibolga
# Processing Record 28 of Set 6 | anloga
# Processing Record 29 of Set 6 | tocopilla
# Processing Record 30 of Set 6 | kattivakkam
# Processing Record 31 of Set 6 | lugovoy
# Processing Record 32 of Set 6 | ngunguru
# Processing Record 33 of Set 6 | flin flon
# Processing Record 34 of Set 6 | havre-saint-pierre
# Processing Record 35 of Set 6 | bathsheba
# Processing Record 36 of Set 6 | lompoc
# Processing Record 37 of Set 6 | yantal
# Processing Record 38 of Set 6 | abalak
# Processing Record 39 of Set 6 | kosikha
# Processing Record 40 of Set 6 | ribeira grande
# Processing Record 41 of Set 6 | jibuti
# Processing Record 42 of Set 6 | kyabe
# Processing Record 43 of Set 6 | orbetello
# Processing Record 44 of Set 6 | boden
# Processing Record 45 of Set 6 | dakar
# Processing Record 46 of Set 6 | meadow lake
# Processing Record 47 of Set 6 | mar del plata
# Processing Record 48 of Set 6 | lensk
# Processing Record 49 of Set 6 | parkes
# Processing Record 50 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 1 of Set 7 | bagdarin
# Processing Record 2 of Set 7 | kidal
# Processing Record 3 of Set 7 | dewas
# Processing Record 4 of Set 7 | cam ranh
# Processing Record 5 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 7 | ampere
# Processing Record 7 of Set 7 | seydi
# Processing Record 8 of Set 7 | maningrida
# Processing Record 9 of Set 7 | trincomalee
# Processing Record 10 of Set 7 | richards bay
# Processing Record 11 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 7 | damphu
# Processing Record 13 of Set 7 | kruisfontein
# Processing Record 14 of Set 7 | fairbanks
# Processing Record 15 of Set 7 | kouroussa
# Processing Record 16 of Set 7 | luderitz
# Processing Record 17 of Set 7 | acarau
# Processing Record 18 of Set 7 | westport
# Processing Record 19 of Set 7 | zholymbet
# Processing Record 20 of Set 7 | margate
# Processing Record 21 of Set 7 | talavera
# Processing Record 22 of Set 7 | sao jose de piranhas
# Processing Record 23 of Set 7 | namibe
# Processing Record 24 of Set 7 | russell
# Processing Record 25 of Set 7 | progreso
# Processing Record 26 of Set 7 | san jose
# Processing Record 27 of Set 7 | porlamar
# Processing Record 28 of Set 7 | cap malheureux
# Processing Record 29 of Set 7 | carnarvon
# Processing Record 30 of Set 7 | leh
# Processing Record 31 of Set 7 | kapuskasing
# Processing Record 32 of Set 7 | tiznit
# Processing Record 33 of Set 7 | portland
# Processing Record 34 of Set 7 | juegang
# Processing Record 35 of Set 7 | kargil
# Processing Record 36 of Set 7 | troitskoye
# Processing Record 37 of Set 7 | aleysk
# Processing Record 38 of Set 7 | fredericksburg
# Processing Record 39 of Set 7 | los llanos de aridane
# Processing Record 40 of Set 7 | simbahan
# Processing Record 41 of Set 7 | swan hill
# Processing Record 42 of Set 7 | mataram
# Processing Record 43 of Set 7 | lyuban
# Processing Record 44 of Set 7 | ouesso
# Processing Record 45 of Set 7 | tafalla
# Processing Record 46 of Set 7 | kiama
# Processing Record 47 of Set 7 | san rafael
# Processing Record 48 of Set 7 | acari
# Processing Record 49 of Set 7 | karlstad
# Processing Record 50 of Set 7 | makushino
# Processing Record 1 of Set 8 | codrington
# Processing Record 2 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 8 | antalaha
# Processing Record 5 of Set 8 | innisfail
# Processing Record 6 of Set 8 | otjiwarongo
# Processing Record 7 of Set 8 | buchanan
# Processing Record 8 of Set 8 | semnan
# Processing Record 9 of Set 8 | mizdah
# Processing Record 10 of Set 8 | sola
# Processing Record 11 of Set 8 | barrow
# Processing Record 12 of Set 8 | urumqi
# Processing Record 13 of Set 8 | kavaratti
# Processing Record 14 of Set 8 | teguldet
# Processing Record 15 of Set 8 | dwarka
# Processing Record 16 of Set 8 | mayo
# Processing Record 17 of Set 8 | monticello
# Processing Record 18 of Set 8 | polunochnoye
# Processing Record 19 of Set 8 | saint george
# Processing Record 20 of Set 8 | deputatskiy
# Processing Record 21 of Set 8 | jumla
# Processing Record 22 of Set 8 | goundam
# Processing Record 23 of Set 8 | beringovskiy
# Processing Record 24 of Set 8 | buenos aires
# Processing Record 25 of Set 8 | bambanglipuro
# Processing Record 26 of Set 8 | bayan
# Processing Record 27 of Set 8 | hunza
# City not found. Skipping...
# Processing Record 28 of Set 8 | saint combs
# City not found. Skipping...
# Processing Record 29 of Set 8 | zarubino
# Processing Record 30 of Set 8 | dikson
# Processing Record 31 of Set 8 | tateyama
# Processing Record 32 of Set 8 | sterlitamak
# Processing Record 33 of Set 8 | sikeston
# Processing Record 34 of Set 8 | miles city
# Processing Record 35 of Set 8 | nashua
# Processing Record 36 of Set 8 | felidhoo
# City not found. Skipping...
# Processing Record 37 of Set 8 | yeppoon
# Processing Record 38 of Set 8 | mnogovershinnyy
# Processing Record 39 of Set 8 | san joaquin
# Processing Record 40 of Set 8 | black river
# Processing Record 41 of Set 8 | verkhnevilyuysk
# Processing Record 42 of Set 8 | bandarbeyla
# Processing Record 43 of Set 8 | miraflores
# Processing Record 44 of Set 8 | krasnoye
# Processing Record 45 of Set 8 | gritsovskiy
# Processing Record 46 of Set 8 | san francisco
# Processing Record 47 of Set 8 | benemerito de las americas
# Processing Record 48 of Set 8 | dumai
# Processing Record 49 of Set 8 | cabedelo
# Processing Record 50 of Set 8 | grenada
# Processing Record 1 of Set 9 | canutama
# Processing Record 2 of Set 9 | houma
# Processing Record 3 of Set 9 | gijon
# Processing Record 4 of Set 9 | poya
# Processing Record 5 of Set 9 | yar-sale
# Processing Record 6 of Set 9 | itarema
# Processing Record 7 of Set 9 | licheng
# Processing Record 8 of Set 9 | hongjiang
# Processing Record 9 of Set 9 | tiksi
# Processing Record 10 of Set 9 | bintulu
# Processing Record 11 of Set 9 | erzincan
# Processing Record 12 of Set 9 | lavrentiya
# Processing Record 13 of Set 9 | sakakah
# Processing Record 14 of Set 9 | saurimo
# Processing Record 15 of Set 9 | haines junction
# Processing Record 16 of Set 9 | cayenne
# Processing Record 17 of Set 9 | karema
# Processing Record 18 of Set 9 | vermillion
# Processing Record 19 of Set 9 | karamay
# City not found. Skipping...
# Processing Record 20 of Set 9 | tucurui
# Processing Record 21 of Set 9 | abha
# Processing Record 22 of Set 9 | chimoio
# Processing Record 23 of Set 9 | batagay-alyta
# Processing Record 24 of Set 9 | saint-joseph
# Processing Record 25 of Set 9 | belmonte
# Processing Record 26 of Set 9 | leninskoye
# Processing Record 27 of Set 9 | harper
# Processing Record 28 of Set 9 | ise
# Processing Record 29 of Set 9 | san andres
# Processing Record 30 of Set 9 | coquimbo
# Processing Record 31 of Set 9 | antofagasta
# Processing Record 32 of Set 9 | urengoy
# Processing Record 33 of Set 9 | yayva
# Processing Record 34 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 35 of Set 9 | yulara
# Processing Record 36 of Set 9 | necochea
# Processing Record 37 of Set 9 | mehamn
# Processing Record 38 of Set 9 | oktyabrskoye
# Processing Record 39 of Set 9 | husavik
# Processing Record 40 of Set 9 | west lafayette
# Processing Record 41 of Set 9 | teseney
# Processing Record 42 of Set 9 | grand gaube
# Processing Record 43 of Set 9 | alofi
# Processing Record 44 of Set 9 | hof
# Processing Record 45 of Set 9 | calama
# Processing Record 46 of Set 9 | iranshahr
# Processing Record 47 of Set 9 | praia
# Processing Record 48 of Set 9 | makakilo city
# Processing Record 49 of Set 9 | chernyshevskiy
# Processing Record 50 of Set 9 | okhotsk
# Processing Record 1 of Set 10 | katobu
# Processing Record 2 of Set 10 | jamkhed
# Processing Record 3 of Set 10 | ormara
# Processing Record 4 of Set 10 | quelimane
# Processing Record 5 of Set 10 | odweyne
# Processing Record 6 of Set 10 | ugoofaaru
# Processing Record 7 of Set 10 | padang
# Processing Record 8 of Set 10 | dunmore town
# Processing Record 9 of Set 10 | nanortalik
# Processing Record 10 of Set 10 | kirakira
# Processing Record 11 of Set 10 | thunder bay
# Processing Record 12 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 10 | jambusar
# Processing Record 14 of Set 10 | ketchikan
# Processing Record 15 of Set 10 | okha
# Processing Record 16 of Set 10 | grindavik
# Processing Record 17 of Set 10 | porto walter
# Processing Record 18 of Set 10 | price
# Processing Record 19 of Set 10 | birjand
# Processing Record 20 of Set 10 | adrar
# Processing Record 21 of Set 10 | turtas
# Processing Record 22 of Set 10 | anjangaon
# Processing Record 23 of Set 10 | aranos
# Processing Record 24 of Set 10 | karakendzha
# City not found. Skipping...
# Processing Record 25 of Set 10 | bongandanga
# Processing Record 26 of Set 10 | angoram
# Processing Record 27 of Set 10 | ayr
# Processing Record 28 of Set 10 | guiratinga
# Processing Record 29 of Set 10 | shambu
# Processing Record 30 of Set 10 | guanambi
# Processing Record 31 of Set 10 | ternate
# Processing Record 32 of Set 10 | christchurch
# Processing Record 33 of Set 10 | palana
# Processing Record 34 of Set 10 | atasu
# Processing Record 35 of Set 10 | roma
# Processing Record 36 of Set 10 | botou
# Processing Record 37 of Set 10 | marawi
# Processing Record 38 of Set 10 | trogir
# Processing Record 39 of Set 10 | caravelas
# Processing Record 40 of Set 10 | beloha
# Processing Record 41 of Set 10 | biak
# Processing Record 42 of Set 10 | sayat
# Processing Record 43 of Set 10 | liptovsky hradok
# Processing Record 44 of Set 10 | istok
# Processing Record 45 of Set 10 | half moon bay
# Processing Record 46 of Set 10 | takoradi
# Processing Record 47 of Set 10 | kharan
# Processing Record 48 of Set 10 | burgeo
# Processing Record 49 of Set 10 | amboasary
# Processing Record 50 of Set 10 | robertsport
# Processing Record 1 of Set 11 | kisangani
# Processing Record 2 of Set 11 | loreto
# Processing Record 3 of Set 11 | kaihua
# Processing Record 4 of Set 11 | nhulunbuy
# Processing Record 5 of Set 11 | rulenge
# Processing Record 6 of Set 11 | majene
# Processing Record 7 of Set 11 | awbari
# Processing Record 8 of Set 11 | jining
# Processing Record 9 of Set 11 | poronaysk
# Processing Record 10 of Set 11 | dingle
# Processing Record 11 of Set 11 | honningsvag
# Processing Record 12 of Set 11 | atambua
# Processing Record 13 of Set 11 | oranjemund
# Processing Record 14 of Set 11 | lacarak
# Processing Record 15 of Set 11 | tilichiki
# Processing Record 16 of Set 11 | batemans bay
# Processing Record 17 of Set 11 | merauke
# Processing Record 18 of Set 11 | tevriz
# Processing Record 19 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 11 | simoes
# Processing Record 21 of Set 11 | muisne
# Processing Record 22 of Set 11 | dezful
# Processing Record 23 of Set 11 | mount isa
# Processing Record 24 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 25 of Set 11 | gat
# Processing Record 26 of Set 11 | sinop
# Processing Record 27 of Set 11 | mabaruma
# Processing Record 28 of Set 11 | zharkent
# Processing Record 29 of Set 11 | payson
# Processing Record 30 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 31 of Set 11 | ust-nera
# Processing Record 32 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 33 of Set 11 | capim grosso
# Processing Record 34 of Set 11 | santa maria
# Processing Record 35 of Set 11 | chazuta
# Processing Record 36 of Set 11 | general roca
# Processing Record 37 of Set 11 | palu
# Processing Record 38 of Set 11 | san juan
# Processing Record 39 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 11 | mazagao
# Processing Record 41 of Set 11 | zaraza
# Processing Record 42 of Set 11 | destin
# Processing Record 43 of Set 11 | maniitsoq
# Processing Record 44 of Set 11 | coahuayana
# Processing Record 45 of Set 11 | kazanskaya
# Processing Record 46 of Set 11 | naantali
# Processing Record 47 of Set 11 | shar
# Processing Record 48 of Set 11 | hlotse
# Processing Record 49 of Set 11 | pringsewu
# Processing Record 50 of Set 11 | varna
# Processing Record 1 of Set 12 | nowy dwor gdanski
# Processing Record 2 of Set 12 | milledgeville
# Processing Record 3 of Set 12 | villa sandino
# Processing Record 4 of Set 12 | chalons-en-champagne
# Processing Record 5 of Set 12 | leningradskiy
# Processing Record 6 of Set 12 | paita
# Processing Record 7 of Set 12 | minot
# Processing Record 8 of Set 12 | voh
# Processing Record 9 of Set 12 | governador valadares
# Processing Record 10 of Set 12 | riosucio
# Processing Record 11 of Set 12 | nanakuli
# Processing Record 12 of Set 12 | pontian kecil
# Processing Record 13 of Set 12 | sitka
# Processing Record 14 of Set 12 | mahadday weyne
# City not found. Skipping...
# Processing Record 15 of Set 12 | sheridan
# Processing Record 16 of Set 12 | anzio
# Processing Record 17 of Set 12 | heihe
# Processing Record 18 of Set 12 | samandag
# Processing Record 19 of Set 12 | santa isabel do rio negro
# Processing Record 20 of Set 12 | manuk mangkaw
# Processing Record 21 of Set 12 | batangafo
# Processing Record 22 of Set 12 | baruun-urt
# Processing Record 23 of Set 12 | conde
# Processing Record 24 of Set 12 | del pilar
# Processing Record 25 of Set 12 | pangnirtung
# Processing Record 26 of Set 12 | palmer
# Processing Record 27 of Set 12 | williamsburg
# Processing Record 28 of Set 12 | ostersund
# Processing Record 29 of Set 12 | hengshui
# Processing Record 30 of Set 12 | chumikan
# Processing Record 31 of Set 12 | nuuk
# Processing Record 32 of Set 12 | monywa
# Processing Record 33 of Set 12 | luzhou
# Processing Record 34 of Set 12 | buraydah
# Processing Record 35 of Set 12 | itaituba
# Processing Record 36 of Set 12 | kimbe
# Processing Record 37 of Set 12 | saint-francois
# Processing Record 38 of Set 12 | aklavik
# Processing Record 39 of Set 12 | najran
# Processing Record 40 of Set 12 | rusape
# Processing Record 41 of Set 12 | mogadishu
# Processing Record 42 of Set 12 | aykhal
# Processing Record 43 of Set 12 | menongue
# Processing Record 44 of Set 12 | suicheng
# Processing Record 45 of Set 12 | manta
# Processing Record 46 of Set 12 | kalmunai
# Processing Record 47 of Set 12 | rayagada
# Processing Record 48 of Set 12 | maxixe
# Processing Record 49 of Set 12 | rincon
# Processing Record 50 of Set 12 | lerwick
# Processing Record 1 of Set 13 | olga
# Processing Record 2 of Set 13 | japura
# Processing Record 3 of Set 13 | beyla
# Processing Record 4 of Set 13 | ballina
# Processing Record 5 of Set 13 | narasannapeta
# Processing Record 6 of Set 13 | quijingue
# Processing Record 7 of Set 13 | nouadhibou
# Processing Record 8 of Set 13 | meghri
# Processing Record 9 of Set 13 | uruzgan
# Processing Record 10 of Set 13 | hobyo
# Processing Record 11 of Set 13 | havre
# Processing Record 12 of Set 13 | beringen
# Processing Record 13 of Set 13 | bubaque
# Processing Record 14 of Set 13 | kloulklubed
# Processing Record 15 of Set 13 | marmaron
# City not found. Skipping...
# Processing Record 16 of Set 13 | charters towers
# Processing Record 17 of Set 13 | hakkari
# Processing Record 18 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 13 | juneau
# Processing Record 20 of Set 13 | vostok
# Processing Record 21 of Set 13 | galesong
# Processing Record 22 of Set 13 | ucluelet
# Processing Record 23 of Set 13 | altamira
# Processing Record 24 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 25 of Set 13 | cadiz
# Processing Record 26 of Set 13 | riyaq
# City not found. Skipping...
# Processing Record 27 of Set 13 | amapa
# Processing Record 28 of Set 13 | bardiyah
# Processing Record 29 of Set 13 | gazanjyk
# Processing Record 30 of Set 13 | hay river
# Processing Record 31 of Set 13 | srednekolymsk
# Processing Record 32 of Set 13 | edd
# Processing Record 33 of Set 13 | iskateley
# Processing Record 34 of Set 13 | cedar city
# Processing Record 35 of Set 13 | sergeyevka
# Processing Record 36 of Set 13 | buchin
# Processing Record 37 of Set 13 | atalaia
# Processing Record 38 of Set 13 | santa isabel
# Processing Record 39 of Set 13 | bloemfontein
# Processing Record 40 of Set 13 | zhanaozen
# Processing Record 41 of Set 13 | santa rosalia
# Processing Record 42 of Set 13 | nanao
# Processing Record 43 of Set 13 | waingapu
# Processing Record 44 of Set 13 | enumclaw
# Processing Record 45 of Set 13 | taoudenni
# Processing Record 46 of Set 13 | meulaboh
# Processing Record 47 of Set 13 | salinopolis
# Processing Record 48 of Set 13 | balkhash
# Processing Record 49 of Set 13 | morehead
# Processing Record 50 of Set 13 | almaznyy
# Processing Record 1 of Set 14 | kursenai
# Processing Record 2 of Set 14 | arroio grande
# Processing Record 3 of Set 14 | tuxpan
# Processing Record 4 of Set 14 | karachi
# Processing Record 5 of Set 14 | severo-kurilsk
# Processing Record 6 of Set 14 | matara
# Processing Record 7 of Set 14 | ranong
# Processing Record 8 of Set 14 | zachagansk
# City not found. Skipping...
# Processing Record 9 of Set 14 | camden
# Processing Record 10 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 11 of Set 14 | bosaso
# Processing Record 12 of Set 14 | komsomolskiy
# Processing Record 13 of Set 14 | asau
# Processing Record 14 of Set 14 | la asuncion
# Processing Record 15 of Set 14 | dracena
# Processing Record 16 of Set 14 | carballo
# Processing Record 17 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 14 | ismailia
# Processing Record 19 of Set 14 | vila franca do campo
# Processing Record 20 of Set 14 | nola
# Processing Record 21 of Set 14 | manggar
# Processing Record 22 of Set 14 | arman
# Processing Record 23 of Set 14 | chirongui
# Processing Record 24 of Set 14 | nuevitas
# Processing Record 25 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 26 of Set 14 | kupang
# Processing Record 27 of Set 14 | yatou
# Processing Record 28 of Set 14 | bull savanna
# Processing Record 29 of Set 14 | sept-iles
# Processing Record 30 of Set 14 | yomitan
# City not found. Skipping...
# Processing Record 31 of Set 14 | marsh harbour
# Processing Record 32 of Set 14 | bikaner
# Processing Record 33 of Set 14 | ishigaki
# Processing Record 34 of Set 14 | tunxi
# City not found. Skipping...
# Processing Record 35 of Set 14 | pervomayskiy
# Processing Record 36 of Set 14 | lasa
# Processing Record 37 of Set 14 | egersund
# Processing Record 38 of Set 14 | sinnamary
# Processing Record 39 of Set 14 | ponta delgada
# Processing Record 40 of Set 14 | lufilufi
# Processing Record 41 of Set 14 | maymyo
# Processing Record 42 of Set 14 | santa marta
# Processing Record 43 of Set 14 | tacna
# Processing Record 44 of Set 14 | gazli
# Processing Record 45 of Set 14 | sayyan
# Processing Record 46 of Set 14 | bukoba
# Processing Record 47 of Set 14 | zhigansk
# Processing Record 48 of Set 14 | uspantan
# Processing Record 49 of Set 14 | mackay
# Processing Record 50 of Set 14 | asekeyevo
# Processing Record 1 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 2 of Set 15 | sisimiut
# Processing Record 3 of Set 15 | saint-georges
# Processing Record 4 of Set 15 | kudahuvadhoo
# Processing Record 5 of Set 15 | lovington
# Processing Record 6 of Set 15 | loa janan
# Processing Record 7 of Set 15 | hangu
# Processing Record 8 of Set 15 | qasigiannguit
# Processing Record 9 of Set 15 | santa lucia
# Processing Record 10 of Set 15 | awjilah
# Processing Record 11 of Set 15 | port macquarie
# Processing Record 12 of Set 15 | rochester
# Processing Record 13 of Set 15 | mae ramat
# Processing Record 14 of Set 15 | gisborne
# Processing Record 15 of Set 15 | bartica
# Processing Record 16 of Set 15 | jamalpur
# Processing Record 17 of Set 15 | stoyba
# City not found. Skipping...
# Processing Record 18 of Set 15 | mulchen
# Processing Record 19 of Set 15 | parnamirim
# Processing Record 20 of Set 15 | weligama
# Processing Record 21 of Set 15 | beyneu
# Processing Record 22 of Set 15 | bluefields
# Processing Record 23 of Set 15 | alice springs
# Processing Record 24 of Set 15 | karratha
# Processing Record 25 of Set 15 | prabumulih
# Processing Record 26 of Set 15 | asfi
# Processing Record 27 of Set 15 | hot springs
# Processing Record 28 of Set 15 | kadoma
# Processing Record 29 of Set 15 | normandin
# Processing Record 30 of Set 15 | atascadero
# Processing Record 31 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 32 of Set 15 | puquio
# Processing Record 33 of Set 15 | barcelos
# Processing Record 34 of Set 15 | cervo
# Processing Record 35 of Set 15 | latung
# Processing Record 36 of Set 15 | shirgaon
# Processing Record 37 of Set 15 | bembereke
# Processing Record 38 of Set 15 | inongo
# Processing Record 39 of Set 15 | havelock
# Processing Record 40 of Set 15 | wewak
# Processing Record 41 of Set 15 | nador
# Processing Record 42 of Set 15 | camalu
# Processing Record 43 of Set 15 | mao
# Processing Record 44 of Set 15 | mokobeng
# Processing Record 45 of Set 15 | lovozero
# Processing Record 46 of Set 15 | billings
# Processing Record 47 of Set 15 | minador do negrao
# Processing Record 48 of Set 15 | galveston
# Processing Record 49 of Set 15 | carquefou
# Processing Record 50 of Set 15 | sexsmith
# Processing Record 1 of Set 16 | biloela
# Processing Record 2 of Set 16 | kortkeros
# Processing Record 3 of Set 16 | glyadyanskoye
# Processing Record 4 of Set 16 | goulburn
# Processing Record 5 of Set 16 | sapanta
# Processing Record 6 of Set 16 | marsabit
# Processing Record 7 of Set 16 | araouane
# Processing Record 8 of Set 16 | rundu
# Processing Record 9 of Set 16 | pionerskiy
# Processing Record 10 of Set 16 | sereflikochisar
# Processing Record 11 of Set 16 | guanica
# Processing Record 12 of Set 16 | mount gambier
# Processing Record 13 of Set 16 | gizo
# Processing Record 14 of Set 16 | nemuro
# Processing Record 15 of Set 16 | belousovka
# Processing Record 16 of Set 16 | camana
# Processing Record 17 of Set 16 | liku
# Processing Record 18 of Set 16 | kannur
# Processing Record 19 of Set 16 | sambava
# Processing Record 20 of Set 16 | iwanai
# Processing Record 21 of Set 16 | taloqan
# Processing Record 22 of Set 16 | yurginskoye
# Processing Record 23 of Set 16 | portachuelo
# Processing Record 24 of Set 16 | zeya
# Processing Record 25 of Set 16 | uige
# Processing Record 26 of Set 16 | nizhniy ingash
# Processing Record 27 of Set 16 | tual
# Processing Record 28 of Set 16 | izumo
# Processing Record 29 of Set 16 | cidreira
# Processing Record 30 of Set 16 | college
# Processing Record 31 of Set 16 | ashtian
# Processing Record 32 of Set 16 | burriana
# Processing Record 33 of Set 16 | durban
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 732

# %%
# Add the data to a new DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Geraldton -28.7667  114.6000     73.81        56          40        8.05
# 1      Atuona  -9.8000 -139.0333     78.48        71           1       16.96
# 2   Busselton -33.6500  115.3333     67.71        52          73       10.80
# 3  Champerico  14.3000  -91.9167     84.31        72          97        3.40
# 4     Ushuaia -54.8000  -68.3000     40.66        87         100        9.22
# 5         Soe  -9.8607  124.2840     85.05        33          44        7.90
# 6        Atar  20.5169  -13.0499     85.42        13         100       12.21
# 7   Coihaique -45.5752  -72.0662     30.81       100           0        2.30
# 8  Georgetown   5.4112  100.3354     89.53        70          20        5.01
# 9     Dudinka  69.4058   86.1778     43.63       100         100        9.33
#
#   Country Current Description
# 0      AU    scattered clouds
# 1      PF           clear sky
# 2      AU       broken clouds
# 3      GT     overcast clouds
# 4      AR          light rain
# 5      ID    scattered clouds
# 6      MR     overcast clouds
# 7      CL           clear sky
# 8      MY          few clouds
# 9      RU     overcast clouds

# %%
# Reorder the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Geraldton      AU -28.7667  114.6000     73.81        56          40
# 1        Atuona      PF  -9.8000 -139.0333     78.48        71           1
# 2     Busselton      AU -33.6500  115.3333     67.71        52          73
# 3    Champerico      GT  14.3000  -91.9167     84.31        72          97
# 4       Ushuaia      AR -54.8000  -68.3000     40.66        87         100
# ..          ...     ...      ...       ...       ...       ...         ...
# 727    Cidreira      BR -30.1811  -50.2056     53.53        75          44
# 728     College      US  64.8569 -147.8028     48.52        70          75
# 729     Ashtian      IR  34.5217   50.0019     56.07        20           2
# 730    Burriana      ES  39.8890   -0.0850     65.70        73           1
# 731      Durban      ZA -29.8579   31.0292     62.02        92           0
#
#      Wind Speed Current Description
# 0          8.05    scattered clouds
# 1         16.96           clear sky
# 2         10.80       broken clouds
# 3          3.40     overcast clouds
# 4          9.22          light rain
# ..          ...                 ...
# 727       24.36    scattered clouds
# 728        4.61       broken clouds
# 729        9.46           clear sky
# 730        2.57           clear sky
# 731        5.01           clear sky
#
# [732 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
